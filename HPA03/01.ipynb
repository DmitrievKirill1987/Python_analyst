# %% [markdown]
# # Условие 1: Задача 1
# Считать данные с помощью pandas
# Вывести на экран первые 5 строк

# %%
import numpy as np
import pandas as pd
file_path = 'C:/Users/User/Desktop/Kirill_GB/Python_analyst/HomeworkPthonAnalitic02/kc_house_data.csv'
df = pd.read_csv(file_path, sep=',', encoding='windows-1251', parse_dates=['date'], dayfirst=True)
df.head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6308\3641378471.py:4: UserWarning: Parsing dates in %Y%m%dT%H%M%S format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   df = pd.read_csv(file_path, sep=',', encoding='windows-1251', parse_dates=['date'], dayfirst=True)
#            id       date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...      7        1180              0  \
# 1      7242     2.0           0     0  ...      7        2170            400
# ...

# %%
df.dtypes
# Out:
# id                        int64
# date             datetime64[ns]
# price                   float64
# bedrooms                  int64
# bathrooms               float64
# sqft_living               int64
# sqft_lot                  int64
# floors                  float64
# waterfront                int64
# view                      int64
# condition                 int64
# grade                     int64
# sqft_above                int64
# sqft_basement             int64
# yr_built                  int64
# yr_renovated              int64
# zipcode                   int64
# lat                     float64
# long                    float64
# sqft_living15             int64
# sqft_lot15                int64
# dtype: object

# %% [markdown]
# 1.2 Создать новый признак delta_renovated, который будет содержать разницу в годах между годом реновацией дома и годом постройки дома. Если реновации дома не было, то в новом признаке поставьте 0

# %%
df['delta_renovated'] = 0
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...        1180              0  \
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15
# ...

# %%
def correct_minus(row):
    if row.yr_renovated == 0:
        row.delta_renovated = 0
    else:
        row.delta_renovated = row.yr_renovated - row.yr_built
    return row

df = df.apply(correct_minus, axis='columns')
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement
# 0      5650     1.0           0     0  ...        1180              0  \
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15
# ...

# %%
df.loc[df['delta_renovated'] != 0]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living
# 1      6414100192 2014-12-09   538000.0         3       2.25         2570  \
# 35     9547205180 2014-06-13   696000.0         3       2.50         2300
# 95     1483300570 2014-09-08   905000.0         4       2.50         3300
# 103    2450000295 2014-10-07  1088000.0         3       2.50         2920
# 115    3626039325 2014-11-21   740500.0         3       3.50         4380
# ...           ...        ...        ...       ...        ...          ...
# 19622  7351200295 2015-01-14  1150000.0         3       1.75         1760
# 20057   126039256 2014-09-04   434900.0         3       2.00         1520
# 20444  4305600360 2015-02-25   500012.0         4       2.50         2400
# 20447  3319500628 2015-02-12   356999.0         3       1.50         1010
# 20962  1278000210 2015-03-11   110000.0         2       1.00          828
#
#        sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement
# ...

# %% [markdown]
# 1.3 Создайте признаки года продажи, месяца продажи

# %%
df['date'].value_counts()
# Out:
# date
# 2014-06-23    142
# 2014-06-26    131
# 2014-06-25    131
# 2014-07-08    127
# 2015-04-27    126
#              ...
# 2014-11-02      1
# 2015-01-31      1
# 2015-05-24      1
# 2014-05-17      1
# 2014-07-27      1
# Name: count, Length: 372, dtype: int64

# %%
df["year"] = df["date"].dt.to_period("Y")
df["mouth"] = df['date'].dt.month
df.head(5)
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180  \
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  yr_built  yr_renovated  zipcode
# 0      5650     1.0           0     0  ...      1955             0    98178  \
# 1      7242     2.0           0     0  ...      1951          1991    98125
# 2     10000     1.0           0     0  ...      1933             0    98028
# 3      5000     1.0           0     0  ...      1965             0    98136
# 4      8080     1.0           0     0  ...      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  delta_renovated  year  mouth
# ...

# %% [markdown]
# - 1.4 Удалите признаки date, zipcode, lat, long

# %%
df.drop(columns=['date', 'zipcode', 'lat', 'long'], inplace=True)
df.sample(5)
# Out:
#                id     price  bedrooms  bathrooms  sqft_living  sqft_lot
# 8544   3523069047  849000.0         4       2.75         4010     87555  \
# 827    1610000016  175000.0         4       1.00         1300      6030
# 20149  2771102144  385000.0         3       3.25         1320      1327
# 9790   2883200875  680200.0         2       1.50         1960      6000
# 17854  5495200040  610000.0         5       3.25         3490     23400
#
#        floors  waterfront  view  condition  grade  sqft_above  sqft_basement
# 8544      2.0           0     0          3     10        4010              0  \
# 827       1.5           0     0          3      6        1300              0
# 20149     2.0           0     0          3      8        1040            280
# 9790      1.0           0     0          3      8        1210            750
# 17854     1.0           0     0          4      8        1890           1600
#
# ...

# %% [markdown]
# # Условие 2: 2 задача
# - 2.0 Создайте датафрейм с клиентами: clients = pd.DataFrame({
# 'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
# 939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
# 2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
# 'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
# 1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
# 5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
# 5083000375, 7920100025, 1951600150, 809001400, 339600110,
# 1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
# 8861700030, 3303980210, 7731100066, 8146100580, 825069097,
# 3889100029, 9524100196]
# })

# %%
clients = pd.DataFrame({
'client_id': [1459, 4684, 3498, 3942, 4535, 2308, 2866, 2765, 1472, 4236, 2295,
939, 3840, 280, 20, 4332, 3475, 4213, 3113, 4809, 2134, 2242,
2068, 4929, 1384, 1589, 3317, 2260, 1727, 1764, 1611, 1474],
'house_id': [8965450190, 6823100225, 5104540330, 2131701075, 1522700060,
1189000207, 6821600300, 7137950720, 9510920050, 6131600255,
5428000070, 1788800910, 8100400160, 3123049142, 6306800010,
5083000375, 7920100025, 1951600150, 809001400, 339600110,
1622049154, 1099600250, 8563000110, 2768100205, 3995700435,
8861700030, 3303980210, 7731100066, 8146100580, 825069097,
3889100029, 9524100196]
})
clients.set_index('client_id', inplace=True)
clients.head(5)
# Out:
#              house_id
# client_id
# 1459       8965450190
# 4684       6823100225
# 3498       5104540330
# 3942       2131701075
# 4535       1522700060

# %% [markdown]
# - 2.1 Присоедините к таблице clients данные по домам через метод join

# %%
new_df = clients.join(df)
new_df.head(5)
# Out:
#              house_id          id      price  bedrooms  bathrooms
# client_id
# 1459       8965450190  3275860270   755000.0         3       2.25  \
# 4684       6823100225  9268200600   413500.0         2       1.00
# 3498       5104540330  9547204350   690000.0         3       2.00
# 3942       2131701075  8861500015   675000.0         3       2.25
# 4535       1522700060  5556300076  1442500.0         3       2.25
#
#            sqft_living  sqft_lot  floors  waterfront  view  ...  grade
# client_id                                                   ...
# 1459              3020     13031     2.0           0     0  ...      9  \
# 4684               770      4000     1.0           0     0  ...      5
# 3498              1610      5100     1.5           0     0  ...      8
# 3942              1990     10260     2.0           0     0  ...      8
# 4535              2630      9705     2.5           0     2  ...      8
#
# ...

# %% [markdown]
# - 2.2 Присоедините к таблице clients данные по домам через метод merge
# Это нужно, чтобы понимать, какие дома покупались клиентами
# house_id - это индексы датафрейма с домами

# %%
df_merge = clients.merge(df, left_on='house_id', right_on='id')
df_merge.head(5)
# Out:
#      house_id          id     price  bedrooms  bathrooms  sqft_living
# 0  8965450190  8965450190  295000.0         3       2.50         1500  \
# 1  6823100225  6823100225  700000.0         4       1.75         1870
# 2  5104540330  5104540330  679000.0         4       2.50         3680
# 3  2131701075  2131701075  420000.0         3       1.75         1720
# 4  1522700060  1522700060  518000.0         4       2.75         2520
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement
# 0      3060     2.0           0     0  ...      7        1500              0  \
# 1      6000     1.0           0     0  ...      8        1670            200
# 2      7236     2.0           0     0  ...     10        3680              0
# 3      5000     1.5           0     0  ...      8        1720              0
# 4     14021     2.0           0     0  ...      9        2520              0
#
#    yr_built  yr_renovated  sqft_living15  sqft_lot15  delta_renovated  year
# ...
